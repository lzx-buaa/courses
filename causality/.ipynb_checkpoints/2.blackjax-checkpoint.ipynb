# %%
import jax
import jax.numpy as jnp
import jax.scipy.stats as stats
import numpy as np

import blackjax

# %%
import matplotlib.pyplot as plt

import arviz as az

az.style.use("dark_background")

# %%
observed = np.random.normal(-10, 20, size=1_000)
az.plot_kde(observed)
# Out:
# <AxesSubplot: >
